# %% [markdown]
# # FUNCTIONS (THEORY QUESTIONS)

# %% [markdown]
# # 1. What is the difference between a function and a method in Python?
#      - In python both functions and methods are blocks of reusable code designed to perform specific tasks, but their key difference lies in their association with objects and classes.
#
#      Function is user defined whereas method is predefined.
#      🔹 Function
#     A function is an independent block of code that performs a task.
#     Defined using def (outside of a class).
#     Not bound to any object.
#     Called like: function_name().
#
#      🔹 Method
#     A method is a function defined inside a class.
#     Bound to an object.
#     Takes self as the first parameter (for instance methods).
#     Called like: object.method_name().
#
# # 2. Explain the concept of function arguments and parameters in Python.
#    - i)Variables passed into the function. Functions can have multiple parameters or none at all.
#
#     ii)A variable in the function definition that receives a value is called a parameters.
#
#     iii)The actual value passed to the function when it is called argument.
#
#     iv)Parameters are the names you write in the function definition.
#
#     v)Arguments are the values you pass when calling the function.

# %%
def greet("name"):  #name is parameter
  print("ayushi")

  greet("ayushi") #ayushi is argument

# %% [markdown]
# # 3. What are the different ways to define and call a function in Python?
#    - In Python, you can define and call functions in various ways, depending on your needs. Here's a breakdown:
#
# 🔹 1. Standard Function Definition
#     >>Defined using def keyword

# %%
def greet():        #defining the function
    print("Hello!")

greet()   #calling the function
# Out:
# Hello!

# %% [markdown]
# 2. Function with Parameters >>Accepts input values(parameters)

# %%
def greet(name):        #defining function with parameters
    print(f"Hello, {name}!")

greet("Ayushi")   #calling the function with arguments
# Out:
# Hello, Ayushi!

# %% [markdown]
# 3. Function with Default Parameters >> Uses default values if arguments are not passed.

# %%
# Function to find sum of 3 numbers
def sum_(a=0, b=0, c=0):      #defining function with parameters
  return a+b+c

sum_(1,2,3)                  #calling the default function
# Out:
# 6

# %% [markdown]
# #4. What is the purpose of the `return` statement in a Python function?
#   - It determines the value that the function will return. If not included, the function defaults to returning None. It is used to to send a result (value) back to the caller and exit the function.
#   1 Return a Value
#     >>It gives back a result from the function to wherever it was called.
#
#   2. End Function Execution
#     >>The return statement immediately stops the function. Any code after it won’t run.
#
#   3. Return Multiple Values
#     >>You can return multiple values as a tuple.
#
#   4. Return Nothing (None)
#     >>If you don't use return, or write return without a value, the function returns None.

# %%
#example of a return statement in python
def add(a, b):
    return a + b

result = add(3, 5)
print(result)  # Output: 8
# Out:
# 8

# %% [markdown]
# #5. What are iterators in Python and how do they differ from iterables?
#   - An iterator is an object that allows traversal through a countable number of values.t is used to iterate over iterable objects like lists, tuples, sets, etc.
#    An interable is any python object/sequential structure/data structure that is capable to return its members one at a time.
#    - permitivity it to be iterated over in a for loop.
#    - EXAMPLES = list, tuples
#    - it uses for loop or while loop
#    - Iteration is a process of looping through the elements of an iterable(list,string) done using a loop.
#    - The process of returning element one by one is called iteration.
#    - Iterator is an object representing a stream of data>> return the data one by one

# %%
 #example of iteration
s="pwskills"
for i in s:
  print(i)
# Out:
# p
# w
# s
# k
# i
# l
# l
# s

# %% [markdown]
# #6.  Explain the concept of generators in Python and how they are defined.
#     - Generator functions in Python are a way to create iterators in a more concise and memory-efficient manner.
#
#     i)These functions allow you to iterate over a potentially large sequence of data without loading the entire sequence into memory.
#
#     ii)The main difference between a regular function and a generator function is that the latter uses the yield keyword to produce a series of values over time, one at a time, rather than returning a single result.
#
#     Working Process of Generator Functions:
#     - Use of yield: Instead of using return to send a value back to the caller, a generator function uses ‘yield’.
#     When the generator function encounters a ‘yield’ statement, it returns the value specified in the yield and pauses its execution state. The next time the generator is called, it resumes from where it left off.

# %%
#Defining a generator>> using a function with yield
def count_up_to(n):
    i = 1
    while i <= n:
        yield i
        i += 1
gen = count_up_to(3)    #using it
print(next(gen))
# Out:
# 1

# %% [markdown]
# #7. What are the advantages of using generators over regular functions?
#   - 1.Memory Efficiency
#     i)Generators don’t store all values in memory.
#     ii)They generate items one at a time and only when needed.
#     iii)It is Useful when working with large datasets or files.
#
#     2.Faster Start Time
#     A generator starts execution immediately, unlike functions that build full data structures first.
#
#     3.Lazy Evaluation
#     Values are generated on demand using next(), making them suitable for streaming data or infinite sequences.
#
#     4.Infinite Sequences
#     Generators can produce values forever without using infinite memory.
#
#     5.Cleaner Code for Iteration
#     Generator functions replace complex iterator classes with simpler code.
#
#     6.Pause and Resume Execution
#     A generator remembers its state between calls to next() — no need for external tracking variables.

# %%
# Regular function returns entire list
def get_numbers_list(n):
    return [i for i in range(n)]

# Generator yields one value at a time
def get_numbers_gen(n):
    for i in range(n):
        yield i

# %% [markdown]
# #8. What is a lambda function in Python and when is it typically used?
#    - Lambda functions are small, anonymous functions defined using the lambda keyword. They are used for creating small, throwaway functions without the need to formally define a function using def.
#
#     i)A lambda function in Python is a concise way to create anonymous functions, also known as lambda expressions.
#
#     ii)Unlike regular functions defined using the def keyword, lambda functions are often used for short-term operations and are defined in a single line.
#
#     A lambda in Python is used to create small, anonymous (unnamed) functions in a single line, usually when a full def function is unnecessary.
#
#    1. Used as an Argument to Functions
#     Especially with functions like map(), filter(), and sorted().
#     Example with map():
#
#    2. Used with filter()
#     To filter elements based on a condition.
#
#    3. Used with sorted() and key parameter
#     To sort based on a custom logic.
#
#    4. In GUI or Event Handling Code
#     Where quick functions are needed for buttons or actions.

# %% [markdown]
#  # 9. Explain the purpose and usage of the `map()` function in Python.
#      -The map function applies a given function to all items in an input iterable (like a list) and returns an iterator with the results.
#
#     i)The `map()` function executes a specified function for each item in an `iterable`.
#
#     ii)The `map()` function executes a specified function for each item in an `iterable`. The item is sent to thefunction as a parameter.
#
#     iii)The map() function in Python is a built-in function that applies a given function to all the items in an iterable (e.g., a list) and returns an iterable map object (an iterator) of the results.
#
#     Purpose
#     i)To transform all items in an iterable using a given function.
#     ii)Useful for writing cleaner and shorter code without explicit loops.

# %%
def square(x):
    return x * x

numbers = [1, 2, 3, 4]
result = map(square, numbers)
print(list(result))
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# #10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#    - 1.map()
#     Applies a function to each item in an iterable and returns a new iterable (map object).

# %%
#example of map()
numbers = [1, 2, 3, 4]
squared = map(lambda x: x * x, numbers)
print(list(squared))
# Out:
# [1, 4, 9, 16]

# %% [markdown]
#  2.filter()>>
#    Filters items from an iterable based on a condition (Boolean function).

# %%
#syntax of filter()
filter(function, iterable)


#example of filter()
nums = [1, 2, 3, 4]
evens = list(filter(lambda x: x % 2 == 0, nums))
print(evens)

# %% [markdown]
# 3.Reduce()>>Purpose: Applies a function cumulatively to the items of an iterable, reducing it to a single value. It is available in the functools module.
#
# Usage: When you want to reduce an iterable to a single value (like summing numbers or finding a product).

# %%
#example of reduce()
from functools import reduce
numbers = [1, 2, 3, 4]
product = reduce(lambda x, y: x * y, numbers)
print(product)
# Out:
# 24

# %% [markdown]
# # 11. Write the internal mechanism for sum operation using  reduce function[47,11,42,13].![WhatsApp Image 2025-07-19 at 23.21.05.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #PRACTICAL QUESTIONS

# %% [markdown]
# # 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# %%
def sum_of_evens(numbers):
    return sum(num for num in numbers if num % 2 == 0)

numbers = [47, 11, 42, 13, 6, 8]
result = sum_of_evens(numbers)
print("Sum of even numbers:", result)
# Out:
# Sum of even numbers: 56

# %% [markdown]
# #2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(s):
    return s[::-1]

# Example usage
input_string = "superman"
reversed_string = reverse_string(input_string)
print("Reversed string:", reversed_string)
# Out:
# Reversed string: namrepus

# %% [markdown]
# #3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
def square_numbers(numbers):
    return [num ** 2 for num in numbers]

# Example usage
input_numbers = [1, 2, 3, 4, 5]
squared_numbers = square_numbers(input_numbers)
print("Squared numbers:", squared_numbers)
# Out:
# Squared numbers: [1, 4, 9, 16, 25]

# %% [markdown]
# # 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(n):
    # Check if the number is less than 2
    if n <= 1:
        return False

    # Check divisibility from 2 to sqrt(n)
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False  # n is divisible by i, so it's not prime

    return True  # n is prime

# Get user input
user_input = int(input("Enter a number between 1 and 200 to check if it's prime: "))

# Check if the input is within the valid range
if 1 <= user_input <= 200:
    if is_prime(user_input):
        print(f"{user_input} is a prime number.")
    else:
        print(f"{user_input} is not a prime number.")
else:
    print("Please enter a number between 1 and 200.")
# Out:
# Enter a number between 1 and 200 to check if it's prime: 48
# 48 is not a prime number.

# %% [markdown]
# # 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# %%
class FibonacciIterator:
    def __init__(self, n):
        self.n = n
        self.a, self.b = 0, 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n:
            raise StopIteration

        fibonacci_number = self.a
        self.a, self.b = self.b, self.a + self.b
        self.count += 1
        return fibonacci_number

num_terms = int(input("Enter the number of Fibonacci terms you want: "))
fibonacci_sequence = FibonacciIterator(num_terms)

for number in fibonacci_sequence:
    print(number,end=" ")
# Out:
# Enter the number of Fibonacci terms you want: 5
# 0 1 1 2 3

# %% [markdown]
# # 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(exponent):
    for i in range(exponent + 1):  # From 0 to the given exponent (inclusive)
        yield 2 ** i  # Yield 2 raised to the power of i

# Example usage:
exponent = int(input("Enter the exponent to generate powers of 2: "))
for power in powers_of_two(exponent):
    print(power,end=" ")
# Out:
# Enter the exponent to generate powers of 2: 4
# 1 2 4 8 16

# %% [markdown]
# # 7.  Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_line_by_line(file_path):
    try:
        with open(file_path, 'r') as file:
            for line in file:
                yield line.strip()  # Yield each line, removing any extra newline characters
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
    except Exception as e:
        print(f"Error: {e}")

# Example usage:
file_path = input("Enter the path to the file: ")
for line in read_file_line_by_line(file_path):
    print(line)
# Out:
# Enter the path to the file: r
# Error: The file 'r' was not found.

# %% [markdown]
# #8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
tuples_list = [(1, 3), (2, 1), (4, 2), (3, 5)]
sorted_tuples = sorted(tuples_list, key=lambda x: x[1])
print("Sorted list based on the second element of each tuple:", sorted_tuples)
# Out:
# Sorted list based on the second element of each tuple: [(2, 1), (4, 2), (1, 3), (3, 5)]

# %% [markdown]
# #9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
celsius_temperatures = [0, 10, 50, 80, 100]
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32
fahrenheit_temperatures = list(map(celsius_to_fahrenheit, celsius_temperatures))
print("Temperatures in Fahrenheit:", fahrenheit_temperatures)
# Out:
# Temperatures in Fahrenheit: [32.0, 50.0, 122.0, 176.0, 212.0]

# %% [markdown]
# #10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
def remove_vowels(char):
    vowels = "aeiouAEIOU"
    return char not in vowels
input_string = input("Enter a string: ")
filtered_string = ''.join(filter(remove_vowels, input_string))
print("String after removing vowels:", filtered_string)
# Out:
# Enter a string: ambulance is on its way
# String after removing vowels: mblnc s n ts wy

# %% [markdown]
#  # 11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:![image.png](data:image/png;base64,...)
#
#
#
#
#
#
#
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map.

# %%
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]
result = list(map(
    lambda order: (order[0], round(order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0), 2)),
    orders
))
print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 84.97)]
